# %%
import pandas as pd
from IPython.display import display

# ============================================================
# ENGINEERED FEATURES SUMMARY TABLE
# ============================================================

engineered_features_summary = pd.DataFrame([

    # ---------------- Numerical × Categorical ----------------

    {
        "Feature Type": "Num × Cat",
        "Dataset Name": "study_quality",
        "Constructed Feature": "heures_etude × méthode_etude",
        "Goal": "Study efficiency by method",
        "Expected Effect": "Some methods improve study effectiveness"
    },

    {
        "Feature Type": "Num × Cat",
        "Dataset Name": "sleep_quality",
        "Constructed Feature": "heures_sommeil × qualité_sommeil",
        "Goal": "Sleep duration vs quality",
        "Expected Effect": "Sleep quality may matter more than duration"
    },

    {
        "Feature Type": "Num × Cat",
        "Dataset Name": "study_school",
        "Constructed Feature": "heures_etude × évaluation_établissement",
        "Goal": "Study efficiency by school quality",
        "Expected Effect": "Better schools may enhance study impact"
    },

    {
        "Feature Type": "Num × Cat",
        "Dataset Name": "study_internet",
        "Constructed Feature": "heures_etude × accès_internet",
        "Goal": "Study efficiency with internet access",
        "Expected Effect": "Internet access may improve learning"
    },

    # ---------------- Ratio Features ----------------

    {
        "Feature Type": "Ratio",
        "Dataset Name": "ratio_study_sleep",
        "Constructed Feature": "heures_etude / heures_sommeil",
        "Goal": "Work/rest balance",
        "Expected Effect": "Balanced lifestyle may improve performance"
    },

    {
        "Feature Type": "Ratio",
        "Dataset Name": "ratio_study_party",
        "Constructed Feature": "heures_etude / heures_fête",
        "Goal": "Academic vs social balance",
        "Expected Effect": "More study than partying may help results"
    },

    {
        "Feature Type": "Ratio",
        "Dataset Name": "ratio_attendance_study",
        "Constructed Feature": "assiduité_classe / heures_etude",
        "Goal": "Class reliance vs self-study",
        "Expected Effect": "Different learning styles may emerge"
    },

    {
        "Feature Type": "Ratio",
        "Dataset Name": "ratio_sleep_party",
        "Constructed Feature": "heures_sommeil / heures_fête",
        "Goal": "Lifestyle discipline",
        "Expected Effect": "Better recovery may stabilize performance"
    },

    {
        "Feature Type": "Ratio",
        "Dataset Name": "ratio_study_attendance",
        "Constructed Feature": "heures_etude / assiduité_classe",
        "Goal": "Self-study emphasis",
        "Expected Effect": "Independent learners may compensate attendance"
    }

])

# Remove default numbering column visually
engineered_features_summary.index = [""] * len(engineered_features_summary)

# Display full text
pd.set_option("display.max_colwidth", None)

display(engineered_features_summary)
# Out:
#  Feature Type            Dataset Name  \
#     Num × Cat           study_quality
#     Num × Cat           sleep_quality
#     Num × Cat            study_school
#     Num × Cat          study_internet
#         Ratio       ratio_study_sleep
#         Ratio       ratio_study_party
#         Ratio  ratio_attendance_study
#         Ratio       ratio_sleep_party
#         Ratio  ratio_study_attendance
#
#                       Constructed Feature  \
#              heures_etude × méthode_etude
#          heures_sommeil × qualité_sommeil
#   heures_etude × évaluation_établissement
#             heures_etude × accès_internet
#             heures_etude / heures_sommeil
#                heures_etude / heures_fête
#           assiduité_classe / heures_etude
#              heures_sommeil / heures_fête
#           heures_etude / assiduité_classe
#
#                                    Goal  \
#              Study efficiency by method
#               Sleep duration vs quality
# ...
